# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/Datasets/DMR_IR"
condition = os.listdir(path)
path_Sick = "/content/drive/MyDrive/Datasets/DMR_IR/Cropped_final/Sick"
path_Healthy = "/content/drive/MyDrive/Datasets/DMR_IR/Cropped_final/Healthy"
sick_cases = os.listdir(path_Sick)
healthy_cases = os.listdir(path_Healthy)
print(condition,sick_cases,healthy_cases)
# Out:
# ['Original', 'Original_Segregated', 'Cropped', 'Cropped_final', 'Removed'] ['422', '413', '425_2', '422_2', '424', '418_2', '425', '418', '415', '412', '411', '410', '409', '402_1', '398', '401', '402', '407', '408', '400', '401_1', '397_1', '397', '393_1', '387', '394', '390', '389', '393', '390_1', '389_1', '386', '385', '378_1', '376', '373_1', '374', '381_1', '378', '381', '384', '384_1', '373', '368', '366_1', '365_1', '371_1', '368_1', '369', '366', '371', '366_2', '365', '361_2', '363', '356', '363_2', '348', '355', '361', '350', '355_2', '347', '346', '337_3', '343', '338', '337', '337_2', '330_2', '342', '344', '345', '330', '328', '320', '287', '319', '318', '326', '318_2', '316', '322', '312', '286', '273', '281', '271', '282', '283', '277', '274', '285', '278', '270', '269', '268', '267', '260', '264', '266', '259', '257', '261', '256', '263', '258', '255', '204', '209', '240', '242', '245', '241', '213', '246', '210', '203', '202', '181', '138_2', '180', '198_2', '192', 
# ...

# %%
os.mkdir(path+"/Segregated")
os.mkdir(path+"/Segregated/Static_frontal")
os.mkdir(path+"/Segregated/Static_right45")
os.mkdir(path+"/Segregated/Static_right90")
os.mkdir(path+"/Segregated/Static_left45")
os.mkdir(path+"/Segregated/Static_left90")
os.mkdir(path+"/Segregated/Dynamic_frontal")
os.mkdir(path+"/Segregated/Dynamic_left45")
os.mkdir(path+"/Segregated/Dynamic_left90")
os.mkdir(path+"/Segregated/Dynamic_right45")
os.mkdir(path+"/Segregated/Dynamic_right90")

# %%
import shutil

# %%
for x in sick_cases:
  case = path_Sick+"/"+str(x)
  print(case)
  case_images = os.listdir(case)
  print(case_images)
  src_dir = case
  print(src_dir)
  for y in case_images:
    print(src_dir+"/"+y)
    image_path = src_dir+"/"+y
    if (y=='Static_frontal.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_right45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_right90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_left45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45/"+y[:13]+"_"+x+".jpg")
    print(y)
    if (y=='Static_left90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90/"+y[:13]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_left90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_left45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_right90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_right45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal1.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal2.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal3.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal4.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal5.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal6.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal7.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal8.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal9.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal10.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal11.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal12.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal13.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal14.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal15.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal16.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal17.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal18.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal19.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
# Out:
# Streaming output truncated to the last 5000 lines.
# Dynamic_frontal8.jpg
# Dynamic_frontal8.jpg
# /content/drive/MyDrive/Datasets/DMR_IR/Cropped_final/Sick/202/Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# Dynamic_frontal13.jpg
# /content/drive/MyDrive/Datasets/DMR_IR/Cropped_final/Sick/202/Dynamic_frontal12.jpg
# Dynamic_frontal12.jpg
# ...

# %%
for x in healthy_cases:
  case = path_Healthy+"/"+str(x)
  print(case)
  case_images = os.listdir(case)
  print(case_images)
  src_dir = case
  print(src_dir)
  for y in case_images:
    print(src_dir+"/"+y)
    image_path = src_dir+"/"+y
    if (y=='Static_frontal.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_frontal/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_right45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right45/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_right90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_right90/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Static_left45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left45/"+y[:13]+"_"+x+".jpg")
    print(y)
    if (y=='Static_left90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Static_left90/"+y[:13]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_left90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left90/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_left45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_left45/"+y[:14]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_right90.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right90/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_right45.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_right45/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:15]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal1.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal2.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal3.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal4.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal5.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal6.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal7.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal8.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal9.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:16]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal10.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal11.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal12.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal13.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal14.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal15.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal16.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal17.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal18.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
    if (y=='Dynamic_frontal19.jpg'):
      dst_dir = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal"
      shutil.copy(image_path, dst_dir)
      cur_f = "/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y
      os.rename(cur_f,"/content/drive/MyDrive/Datasets/DMR_IR/Segregated/Dynamic_frontal/"+y[:17]+"_"+x+".jpg")
    print(y)
# Out:
# Streaming output truncated to the last 5000 lines.
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# Dynamic_frontal14.jpg
# /content/drive/MyDrive/Datasets/DMR_IR/Cropped_final/Healthy/009/Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# Dynamic_right90.jpg
# ...

# %%
print("Static_frontal",len(os.listdir(path+"/Segregated/Static_frontal")))
print("Static_right45",len(os.listdir(path+"/Segregated/Static_right45")))
print("Static_right90",len(os.listdir(path+"/Segregated/Static_right90")))
print("Static_left45",len(os.listdir(path+"/Segregated/Static_left45")))
print("Static_left90",len(os.listdir(path+"/Segregated/Static_left90")))
print("Dynamic_frontal",len(os.listdir(path+"/Segregated/Dynamic_frontal")))
print("Dynamic_left45",len(os.listdir(path+"/Segregated/Dynamic_left45")))
print("Dynamic_left90",len(os.listdir(path+"/Segregated/Dynamic_left90")))
print("Dynamic_right45",len(os.listdir(path+"/Segregated/Dynamic_right45")))
print("Dynamic_right90",len(os.listdir(path+"/Segregated/Dynamic_right90")))
# Out:
# Static_frontal 163
# Static_right45 162
# Static_right90 168
# Static_left45 160
# Static_left90 167
# Dynamic_frontal 3006
# Dynamic_left45 0
# Dynamic_left90 161
# Dynamic_right45 0
# Dynamic_right90 164
