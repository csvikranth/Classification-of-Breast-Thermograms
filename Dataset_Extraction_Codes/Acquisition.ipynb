# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
d= "2012-10-24"
i= "010"
n= "1"
condition = "Healthy"

# %%
images={'Static_frontal': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.S."+d+".00.jpg",
        'Static_right45': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".2.S."+d+".00.jpg",
        'Static_right90': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".3.S."+d+".00.jpg",
        'Static_left45': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".4.S."+d+".00.jpg",
        'Static_left90': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".5.S."+d+".00.jpg",
        'Dynamic_frontal': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".00.jpg",
        'Dynamic_frontal1': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".01.jpg",
        'Dynamic_frontal2': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".02.jpg",
        'Dynamic_frontal3': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".03.jpg",
        'Dynamic_frontal4': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".04.jpg",
        'Dynamic_frontal5': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".05.jpg",
        'Dynamic_frontal6': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".06.jpg",
        'Dynamic_frontal7': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".07.jpg",
        'Dynamic_frontal8': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".08.jpg",
        'Dynamic_frontal9': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".09.jpg",
        'Dynamic_frontal10': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".10.jpg",
        'Dynamic_frontal11': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".11.jpg",
        'Dynamic_frontal12': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".12.jpg",
        'Dynamic_frontal13': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".13.jpg",
        'Dynamic_frontal14': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".14.jpg",
        'Dynamic_frontal15': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".15.jpg",
        'Dynamic_frontal16': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".16.jpg",
        'Dynamic_frontal17': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".17.jpg",
        'Dynamic_frontal18': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".18.jpg",
        'Dynamic_frontal19': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".1.D."+d+".19.jpg",
        'Dynamic_right45': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".2.D."+d+".00.jpg",
        'Dynamic_right90': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".3.D."+d+".00.jpg",
        'Dynamic_left45': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".4.D."+d+".00.jpg",
        'Dynamic_left90': "http://visual.ic.uff.br/dmi/bancovl/0"+i+"/T0"+i+"."+n+".5.D."+d+".00.jpg"}

print(images)
# Out:
# {'Static_frontal': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.S.2012-10-24.00.jpg', 'Static_right45': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.2.S.2012-10-24.00.jpg', 'Static_right90': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.3.S.2012-10-24.00.jpg', 'Static_left45': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.4.S.2012-10-24.00.jpg', 'Static_left90': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.5.S.2012-10-24.00.jpg', 'Dynamic_frontal': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.D.2012-10-24.00.jpg', 'Dynamic_frontal1': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.D.2012-10-24.01.jpg', 'Dynamic_frontal2': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.D.2012-10-24.02.jpg', 'Dynamic_frontal3': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.D.2012-10-24.03.jpg', 'Dynamic_frontal4': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.1.D.2012-10-24.04.jpg', 'Dynamic_frontal5': 'http://visual.ic.uff.br/dmi/bancovl/0010/T0010.1.
# ...

# %%
import os
if n=='1':
  path="/content/drive/MyDrive/Datasets/DMR_IR/"+condition+"/"+i
  os.mkdir(path)
else:
  path="/content/drive/MyDrive/Datasets/DMR_IR/"+condition+"/"+i+"_"+n
  os.mkdir(path)

# %%
import urllib.request
import requests

# %%
r=requests.get(images['Static_frontal'])
if (r):
  urllib.request.urlretrieve(images['Static_frontal'], path+"/Static_frontal.jpg")
r=requests.get(images['Static_right45'])
if (r):
  urllib.request.urlretrieve(images['Static_right45'], path+"/Static_right45.jpg")
r=requests.get(images['Static_right90'])
if (r):
  urllib.request.urlretrieve(images['Static_right90'], path+"/Static_right90.jpg")
r=requests.get(images['Static_left45'])
if (r):
  urllib.request.urlretrieve(images['Static_left45'], path+"/Static_left45.jpg")
r=requests.get(images['Static_left90'])
if (r):
  urllib.request.urlretrieve(images['Static_left90'], path+"/Static_left90.jpg")
r=requests.get(images['Dynamic_frontal'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal'], path+"/Dynamic_frontal.jpg")
r=requests.get(images['Dynamic_frontal1'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal1'], path+"/Dynamic_frontal1.jpg")
r=requests.get(images['Dynamic_frontal2'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal2'], path+"/Dynamic_frontal2.jpg")
r=requests.get(images['Dynamic_frontal3'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal3'], path+"/Dynamic_frontal3.jpg")
r=requests.get(images['Dynamic_frontal4'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal4'], path+"/Dynamic_frontal4.jpg")
r=requests.get(images['Dynamic_frontal5'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal5'], path+"/Dynamic_frontal5.jpg")
r=requests.get(images['Dynamic_frontal6'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal6'], path+"/Dynamic_frontal6.jpg")
r=requests.get(images['Dynamic_frontal7'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal7'], path+"/Dynamic_frontal7.jpg")
r=requests.get(images['Dynamic_frontal8'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal8'], path+"/Dynamic_frontal8.jpg")
r=requests.get(images['Dynamic_frontal9'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal9'], path+"/Dynamic_frontal9.jpg")
r=requests.get(images['Dynamic_frontal10'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal10'], path+"/Dynamic_frontal10.jpg")
r=requests.get(images['Dynamic_frontal11'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal11'], path+"/Dynamic_frontal11.jpg")
r=requests.get(images['Dynamic_frontal12'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal12'], path+"/Dynamic_frontal12.jpg")
r=requests.get(images['Dynamic_frontal13'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal13'], path+"/Dynamic_frontal13.jpg")
r=requests.get(images['Dynamic_frontal14'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal14'], path+"/Dynamic_frontal14.jpg")
r=requests.get(images['Dynamic_frontal15'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal15'], path+"/Dynamic_frontal15.jpg")
r=requests.get(images['Dynamic_frontal16'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal16'], path+"/Dynamic_frontal16.jpg")
r=requests.get(images['Dynamic_frontal17'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal17'], path+"/Dynamic_frontal17.jpg")
r=requests.get(images['Dynamic_frontal18'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal18'], path+"/Dynamic_frontal18.jpg")
r=requests.get(images['Dynamic_frontal19'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_frontal19'], path+"/Dynamic_frontal19.jpg")
r=requests.get(images['Dynamic_right45'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_right45'], path+"/Dynamic_right45.jpg")
r=requests.get(images['Dynamic_right90'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_right90'], path+"/Dynamic_right90.jpg")
r=requests.get(images['Dynamic_left45'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_left45'], path+"/Dynamic_left45.jpg")
r=requests.get(images['Dynamic_left90'])
if (r):
  urllib.request.urlretrieve(images['Dynamic_left90'], path+"/Dynamic_left90.jpg")
