# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
print("healthy_grey_Dynamic_frontal =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Dynamic_frontal'))
      ,"     sick_grey_Dynamic_frontal = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Dynamic_frontal')))
print("healthy_grey_Dynamic_left90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Dynamic_left90'))
,"     sick_grey_Dynamic_left90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Dynamic_left90')))
print("healthy_grey_Dynamic_right90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Dynamic_right90'))
,"     sick_grey_Dynamic_right90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Dynamic_right90')))
print("healthy_grey_Static_frontal =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Static_frontal'))
,"     sick_grey_Static_frontal = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Static_frontal')))
print("healthy_grey_Static_left45 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Static_left45'))
,"     sick_grey_Static_left45 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Static_left45')))
print("healthy_grey_Static_left90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Static_left90'))
,"     sick_grey_Static_left90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Static_left90')))
print("healthy_grey_Static_right45 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Static_right45'))
,"     sick_grey_Static_right45 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Static_right45')))
print("healthy_grey_Static_right90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Healthy/Static_right90'))
,"     sick_grey_Static_right90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Grayscale/Sick/Static_right90')))
# Out:
# healthy_grey_Dynamic_frontal = 2986      sick_grey_Dynamic_frontal =  773
# healthy_grey_Dynamic_left90 = 160      sick_grey_Dynamic_left90 =  40
# healthy_grey_Dynamic_right90 = 163      sick_grey_Dynamic_right90 =  39
# healthy_grey_Static_frontal = 161      sick_grey_Static_frontal =  39
# healthy_grey_Static_left45 = 158      sick_grey_Static_left45 =  39
# healthy_grey_Static_left90 = 165      sick_grey_Static_left90 =  40
# healthy_grey_Static_right45 = 160      sick_grey_Static_right45 =  39
# healthy_grey_Static_right90 = 166      sick_grey_Static_right90 =  40

# %%
print("healthy_pseudocolor_Dynamic_frontal =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Dynamic_frontal'))
      ,"     sick_pseudocolor_Dynamic_frontal = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Dynamic_frontal')))
print("healthy_pseudocolor_Dynamic_left90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Dynamic_left90'))
,"     sick_pseudocolor_Dynamic_left90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Dynamic_left90')))
print("healthy_pseudocolor_Dynamic_right90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Dynamic_right90'))
,"     sick_pseudocolor_Dynamic_right90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Dynamic_right90')))
print("healthy_pseudocolor_Static_frontal =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Static_frontal'))
,"     sick_pseudocolor_Static_frontal = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Static_frontal')))
print("healthy_pseudocolor_Static_left45 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Static_left45'))
,"     sick_pseudocolor_Static_left45 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Static_left45')))
print("healthy_pseudocolor_Static_left90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Static_left90'))
,"     sick_pseudocolor_Static_left90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Static_left90')))
print("healthy_pseudocolor_Static_right45 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Static_right45'))
,"     sick_pseudocolor_Static_right45 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Static_right45')))
print("healthy_pseudocolor_Static_right90 =",len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Healthy/Static_right90'))
,"     sick_pseudocolor_Static_right90 = ", len(os.listdir('/content/drive/MyDrive/Dataset/DMR_IR/Cropped_final_Segregated_colors/Pseudocolor/Sick/Static_right90')))
# Out:
# healthy_pseudocolor_Dynamic_frontal = 20      sick_pseudocolor_Dynamic_frontal =  1508
# healthy_pseudocolor_Dynamic_left90 = 1      sick_pseudocolor_Dynamic_left90 =  72
# healthy_pseudocolor_Dynamic_right90 = 1      sick_pseudocolor_Dynamic_right90 =  78
# healthy_pseudocolor_Static_frontal = 2      sick_pseudocolor_Static_frontal =  74
# healthy_pseudocolor_Static_left45 = 2      sick_pseudocolor_Static_left45 =  75
# healthy_pseudocolor_Static_left90 = 2      sick_pseudocolor_Static_left90 =  75
# healthy_pseudocolor_Static_right45 = 2      sick_pseudocolor_Static_right45 =  72
# healthy_pseudocolor_Static_right90 = 2      sick_pseudocolor_Static_right90 =  79
